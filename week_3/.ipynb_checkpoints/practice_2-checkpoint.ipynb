# %%
import tkinter as tk

#Handling button click event 
def button_click():
    #print("Button Clicked")
     
   #Show an information mesage box 
    msgbox.showinfo("Info", "Welcome to Cos 102 GUI APP!\n")

    #Ask a user confirmation 
    result = msgbox.askyesno("Confirmation", "Do you want to continue")

#Create the main window 
root = tk.Tk()
root.title("Home Page")
root.geometry("300x100")

#Add a label widget 
label = tk.Label(root, text="Hello Frirend \n")
label.pack()

#Add a button widget 
button = tk.Button(root, text="Click Me!", command=button_click)
button.pack()

#Styling the button Widget 
button.config(fg="red", bg="yellow")

#Start the event look 
root.mainloop()

# %%
import tkinter as tk 
from tkinter import messagebox 
from PIL import Image, ImageTk

def welcomeMessage(username):
    #Create a Tkinter window 
    window =tk.TopLevel(root)
    window,title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is Phython GUI with Tkinter")
    label_2.pack



    #Run the Tnkinter event loop 
    root.mainloop()

def submit():
    username = username_entry.get()
    password = password_entry.get()

    if useername =="Mary" and password == "Cos102":
        welcomeMessage(Username)
    else:
        messagebox.showerror("Login", "Invalid username or password")

# %%
# Creater main window 
root =tk.Tk()
root.title("Login Form")
root.geometry("500x200")


#Create username labe; and entry
username_label = tk.Label(root, text="Username:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

#Create password Label and entry 
password_label = tk.Label(root, text="Password:")
password_label.pack()
password_entry = tk.Entry(root, show="*")
password_entry.pack()

#Create submit button 
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

#Run the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\gbeke\Downloads\py\Lib\tkinter\__init__.py", line 2074, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\gbeke\AppData\Local\Temp\ipykernel_17728\1998646053.py", line 25, in submit
#     if useername =="Mary" and password == "Cos102":
#        ^^^^^^^^^
# NameError: name 'useername' is not defined. Did you mean: 'username'?
